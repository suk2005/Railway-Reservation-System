# %%
train = {
    "Train_Number" : 12951,
    "Train Fare" : "Mumbai Rajdhani Express",
    "Source" : "Mumbai",
    "Destination" : "Delhi",
    "Available Seat" : 110
}

# %%
print("Train Information")
print(train)

print("Train Number:", train['Train_Number'])
print("Train Fare:", train['Train Fare'])
print("Source:", train['Source'])
print("Destination:", train['Destination'])
print("Available Seat:", train['Available Seat'])
# Out:
# Train Information
# {'Train_Number': 12951, 'Train Fare': 'Mumbai Rajdhani Express', 'Source': 'Mumbai', 'Destination': 'Delhi', 'Available Seat': 110}
# Train Number: 12951
# Train Fare: Mumbai Rajdhani Express
# Source: Mumbai
# Destination: Delhi
# Available Seat: 110

# %%
train = {
    "Train_Number": 12951,
    "Train_Name": "Mumbai Rajdhani Express",
    "Available_Seats": 120
}

# %%
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 120}

# %%
print("Train_Name:", train["Train_Name"])
print("Available_Seats:", train["Available_Seats"])
# Out:
# Train_Name: Mumbai Rajdhani Express
# Available_Seats: 120

# %%
train["Available_Seats"]=95
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95}

# %%
train["Train_Number"]=12951

# %%
train.pop("Train_Number")
# Out:
# 12951

# %%
print(train)
# Out:
# {'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95}

# %%
train.update({"Platform": 4})
print(train)
# Out:
# {'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95, 'Platform': 4}

# %%
train.pop("Platform")
print(train)
# Out:
# {'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95}
