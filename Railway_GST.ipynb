# %%
passenger_name = "Rahul Sharma"
passenger_age = 28
gender = "Male"
mobile_number = 9876543210

# %%
print("Passenger Name:", passenger_name)
print("Passenger_Age:", passenger_age)
print("Gender:", gender)
print("Mobile_Number:", mobile_number)
# Out:
# Passenger Name: Rahul Sharma
# Passenger_Age: 28
# Gender: Male
# Mobile_Number: 9876543210

# %%
train_name = "Rajdhani_Express"
seat_number = "B2-45"
ticket_price = 2450
journey_date = "25-May-2026"

# %%
print("Train Name:", train_name)
print("Seat Number:", seat_number)
print("Ticket Price:", ticket_price)
print("Journey Date:", journey_date)
# Out:
# Train Name: Rajdhani_Express
# Seat Number: B2-45
# Ticket Price: 2450
# Journey Date: 25-May-2026

# %%
number_of_passengers = 3
ticket_price = 2450

# %%
total_fare = number_of_passengers * ticket_price
print("Total Fare:", total_fare)
# Out:
# Total Fare: 7350

# %%
gst_percentage = 5

# %%
gst_amount = (total_fare * gst_percentage) / 100
print("GST Amount:", gst_amount)
# Out:
# GST Amount: 367.5

# %%
total_fare_with_gst = total_fare + gst_amount
print("Total_Fare_With_GST:", total_fare_with_gst)
# Out:
# Total_Fare_With_GST: 7717.5

# %%
print("-----------------Indian Railway Ticket-------------------")
print("Passenger Name  :", passenger_name)
print("Train Name      :", train_name)
print("Seat Number     :", seat_number)
print("Journey Date    :", journey_date)
print("Passengers      :", number_of_passengers)
print("Ticket Fare     :", total_fare)
print("GST Amount      :", gst_amount)
print("Final Amount    :", total_fare_with_gst)
print("---------------------------------------------------------")
# Out:
# -----------------Indian Railway Ticket-------------------
# Passenger Name  : Rahul Sharma
# Train Name      : Rajdhani_Express
# Seat Number     : B2-45
# Journey Date    : 25-May-2026
# Passengers      : 3
# Ticket Fare     : 7350
# GST Amount      : 367.5
# Final Amount    : 7717.5
# ---------------------------------------------------------

# %%
passenger_name = "Rahul Sharma"
ticket_status = "Confirmed"

# %%
if ticket_status == "Confirmed":
    print("Ticket is Confirmed")
# Out:
# Ticket is Confirmed

# %%
waiting_list = 3

# %%
if waiting_list == 0:
    print("Ticket Confirmed")
else:
    print("Ticket is in Waiting List")
# Out:
# Ticket is in Waiting List

# %%
ticket_status = "RAC"

# %%
if ticket_status == "Confirmed":
    print("Seat Allocated Sucessfully")
elif ticket_status == "RAC":
    print("Partial Reservation Available")
else:
    print("Ticket is in Waiting List")
# Out:
# Partial Reservation Available

# %%
age = 65
if age >= 60:
    print("Passenger Eligible for Senior Citizen Discount")
# Out:
# Passenger Eligible for Senior Citizen Discount

# %%
passenger_age = 25
ticket_confirmed = True

# %%
if passenger_age >= 18 and ticket_confirmed:
    print("Passenger eligible for travel")
# Out:
# Passenger eligible for travel

# %%
valid_id_proof = True
booking_time_valid = True

# %%
if valid_id_proof and booking_time_valid:
   print("Tatkal Booking Allowed")
else:
   print("Tatkal Booking Denied")
# Out:
# Tatkal Booking Allowed

# %%
confirmed_seat = False
rac_seat = True

# %%
if confirmed_seat or rac_seat:
    print("Reservation Available")
# Out:
# Reservation Available

# %%
ticket_cancelled = False

# %%
if not ticket_cancelled:
    print("Ticket is Active")
# Out:
# Ticket is Active

# %%
passenger_age = 65
payment_completed = True

# %%
if passenger_age >= 60 and payment_completed:
    print("Senior Citoizen Reservation Approved")
# Out:
# Senior Citoizen Reservation Approved

# %%
available_seats = 5
payment_status = True

# %%
valid_id_proof = True
booking_time_valid = True

# %%
if valid_id_proof and booking_time_valid:
    print("Tatkal Booking Allowed")
else:
    print("Tatkal Booking Denied")
# Out:
# Tatkal Booking Allowed

# %%
passenger_name = "Rahul Sharma"
passenger_age = 30
available_seats = 2
payment_completed = True
ticket_cancelled = False

# %%
if(passenger_age >= 18 and available_seats > 0 and payment_completed and not ticket_cancelled):
    print("=======================================================")
    print("Indian Railway Reservation")
    print("=======================================================")
    print("Passenger Name     :", passenger_name)
    print("Reservation Status : Confirmed ")
else:
    print("Reservation Failed")
# Out:
# =======================================================
# Indian Railway Reservation
# =======================================================
# Passenger Name     : Rahul Sharma
# Reservation Status : Confirmed
